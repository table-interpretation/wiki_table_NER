# %%
import pandas as pd
import json
import csv
import os
import numpy as np
import torch
import openai
import re
from collections import defaultdict

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import tqdm

# %% [markdown]
# ### Dataset analysis

# %%
entities_path = "../data/entities_gt.csv"
entities = pd.read_csv(entities_path)

# %%
data_path="../data/final_NER_labeled_dataset.csv"
with open(data_path, 'r') as f:
    ner_tables = json.load(f)

# %%
len(ner_tables)
# Out:
# 51271

# %% [markdown]
# ### Check if any tables with only O annotation

# %%
len(ner_tables)
# Out:
# 51271

# %%
empty_tables = []
empty_bio = []
tab_ids = []
num_unique = []
s = 0
j = 0
for idx in range(len(ner_tables)):
    
    ser_correct_annot = []   
    tab_annotation = []
    bio_annotation = []
    
    table = ner_tables[idx][0]
    tab_id = table[0]
    tableHeaders = table[4]
    table_data = table[5]

    row_labels = table[6]
    
    #if tab_id == "102213-2":
    #    print(idx)
    for row in row_labels:       
        for span in row:            
            if len(span)>0:
               # print(span)
                for i in range(len(span)):
                    cls = span[i][-1]
                    if type(cls) == int:
                        tab_annotation.append(cls)
                    else:
                        bio_annotation.append(cls)
                        
    unique_span = set(tab_annotation)
    num_unique.append(len(unique_span))
   
    if all(x==0 for x in tab_annotation):
        s += 1
        empty_tables.append(idx)      
    if all(y=='O' for y in bio_annotation):
        j += 1
        empty_bio.append(idx)
        tab_ids.append(tab_id)

# %%
len(empty_tables)
# Out:
# 0

# %%
ner_tables[160]
# Out:
# [['10222554-1',
#   'Florida State Road 111',
#   'Major junctions',
#   'Major junctions',
#   [[[-1, 0], 'Mile'], [[-1, 1], 'Destinations'], [[-1, 2], 'Notes']],
#   [[[0, 0], '0.0'],
#    [[0, 1],
#     'Category:Jct template transclusions with missing shields SR 21 (Blanding Boulevard)'],
#    [[0, 2], 'Southern terminus'],
#    [[1, 0], '0.4'],
#    [[1, 1],
#     'Category:Jct template transclusions with missing shields SR 128 (San Juan Avenue)'],
#    [[1, 2], ''],
#    [[2, 0], '2.3'],
#    [[2, 1],
#     'Category:Jct template transclusions with missing shields SR 228 (Normandy Boulevard/Post Street)'],
#    [[2, 2], ''],
#    [[3, 0], '2.8'],
#    [[3, 1],
#     'Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields I-10 / SR 8'],
#    [[3, 2], 'Exit 358 (I-10)'],
#    [[4, 0], '3.6'],
#    [[4, 1],
#     'Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields US 90 / SR 10 (West Beaver Street)'],
#    [[4, 2], ''],
#    [[5, 0], '6.7'],
#    [[5, 1],
#     'Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields US 1 / US 23 / SR 5 / SR 15 (New Kings Road)'],
#    [[5, 2], ''],
#    [[6, 0], '9.8'],
#    [[6, 1],
#     'Category:Jct template transclusions with missing shields SR 115 (Lem Turner Road)'],
#    [[6, 2], ''],
#    [[7, 0], '10.5'],
#    [[7, 1],
#     'Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields I-95 / SR 9'],
#    [[7, 2], 'Exit 357 (I-95)'],
#    [[8, 0], '11.9'],
#    [[8, 1],
#     'Category:Jct template transclusions with missing shields Category:Jct template transclusions with missing shields US 17 / SR 5 (North Main Street)'],
#    [[8, 2], 'Northern terminus']],
#   [[[[0, 1, 0, 56, 0], [0, 1, 57, 62, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['21', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['bland', 'O'],
#      ['##ing', 'O'],
#      ['boulevard', 'O'],
#      [')', 'O']]],
#    [[[1, 1, 0, 56, 0], [1, 1, 57, 63, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['128', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['san', 'O'],
#      ['juan', 'O'],
#      ['avenue', 'O'],
#      [')', 'O']]],
#    [[[2, 1, 0, 56, 0], [2, 1, 57, 63, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['228', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['normandy', 'O'],
#      ['boulevard', 'O'],
#      ['/', 'O'],
#      ['post', 'O'],
#      ['street', 'O'],
#      [')', 'O']]],
#    [[[3, 1, 0, 56, 0],
#      [3, 1, 0, 56, 0],
#      [3, 1, 114, 118, 0],
#      [3, 1, 121, 125, 0]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['i', 'O'],
#      ['-', 'O'],
#      ['10', 'O'],
#      ['/', 'O'],
#      ['sr', 'O'],
#      ['8', 'O']]],
#    [[[4, 1, 0, 56, 0],
#      [4, 1, 0, 56, 0],
#      [4, 1, 114, 119, 0],
#      [4, 1, 122, 127, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['us', 'O'],
#      ['90', 'O'],
#      ['/', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['10', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['west', 'O'],
#      ['beaver', 'O'],
#      ['street', 'O'],
#      [')', 'O']]],
#    [[[5, 1, 0, 56, 0],
#      [5, 1, 0, 56, 0],
#      [5, 1, 0, 56, 0],
#      [5, 1, 0, 56, 0],
#      [5, 1, 228, 232, 0],
#      [5, 1, 235, 240, 0],
#      [5, 1, 243, 247, 3],
#      [5, 1, 250, 255, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['us', 'O'],
#      ['1', 'O'],
#      ['/', 'O'],
#      ['us', 'O'],
#      ['23', 'O'],
#      ['/', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['5', 'I-ArchitecturalStructure'],
#      ['/', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['15', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['new', 'O'],
#      ['kings', 'O'],
#      ['road', 'O'],
#      [')', 'O']]],
#    [[[6, 1, 0, 56, 0], [6, 1, 57, 63, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['115', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['le', 'O'],
#      ['##m', 'O'],
#      ['turner', 'O'],
#      ['road', 'O'],
#      [')', 'O']]],
#    [[[7, 1, 0, 56, 0],
#      [7, 1, 0, 56, 0],
#      [7, 1, 114, 118, 0],
#      [7, 1, 121, 125, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['i', 'O'],
#      ['-', 'O'],
#      ['95', 'O'],
#      ['/', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['9', 'I-ArchitecturalStructure']]],
#    [[[8, 1, 0, 56, 0],
#      [8, 1, 0, 56, 0],
#      [8, 1, 114, 119, 0],
#      [8, 1, 122, 126, 3]],
#     [['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['category', 'O'],
#      [':', 'O'],
#      ['jc', 'O'],
#      ['##t', 'O'],
#      ['template', 'O'],
#      ['trans', 'O'],
#      ['##cl', 'O'],
#      ['##usions', 'O'],
#      ['with', 'O'],
#      ['missing', 'O'],
#      ['shields', 'O'],
#      ['us', 'O'],
#      ['17', 'O'],
#      ['/', 'O'],
#      ['sr', 'B-ArchitecturalStructure'],
#      ['5', 'I-ArchitecturalStructure'],
#      ['(', 'O'],
#      ['north', 'O'],
#      ['main', 'O'],
#      ['street', 'O'],
#      [')', 'O']]]]]]

# %%
len(empty_bio)
# Out:
# 22

# %%
sns.set(rc={'figure.figsize':(8,6)})

fig, ax = plt.subplots(1)

sns.histplot(num_unique,kde=False,ax=ax,stat="count",binrange=[1,7], bins=20, color='steelblue')
ax.set(xlabel='Number of unique labels per table', ylabel='Number of tables')
plt.savefig("plots/num_unique_labels_per_table.png")
plt.show()

# %%
for idx in empty_bio:
    del ner_tables[idx][0]

# %%
filtered_tables = [sublist for sublist in ner_tables if len(sublist) > 0]

# %%
len(filtered_tables) # after removing 22 tables which had only 'O' annotation
# Out:
# 51271

# %%
with open('../data/final_NER_labeled_dataset.csv', 'w') as f:
    json.dump(filtered_tables, f)

# %%
with open('../data/final_NER_labeled_dataset_filtered.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# ### Analysis of dataset

# %%
data = ner_tables

# %%
num_cells = []
num_tokens = []
num_unprocessed_rows=[]
num_rows_after_clipping = []
num_diff_labels = []

with tqdm(total=len(dataset)) as progress:
    for i in range(len(dataset)):
        table = dataset.iloc[i]
        table_data = table["tableData"]
        data_rows = [ r for r in table_data ] 
        num_unprocessed_rows.append(len(data_rows))

        cells = [ [cell["tokens_ids"]+[102] for cell in row] for row in data_rows ] # add special classes [CLS] and [SEP]
        num_cells.append(len([c for row in data_rows for c in row]))

        input_ids = torch.cat((torch.tensor([101]),torch.tensor([t for row in cells for cell in row for t in cell])))
        num_tokens.append(input_ids.shape[0])

        input_ids_row = [[t for cell in row for t in cell] for row in cells]
        num_rows=0
        x=0
        rem=511
        while x < len(input_ids_row)-1:
            if len(input_ids_row[x])<rem:
                num_rows+=1
                x+=1
                rem = rem - len(input_ids_row[x])
            else:
                break
        

        labels= [ [cell["mapped"]+[["[SEP]","-100"]] for cell in row] for row in data_rows ]
        linearized_labels= [t[1] for row in labels for cell in row for t in cell]
        if len(linearized_labels)<511:
            linearized_labels=linearized_labels[:512]

        num_diff_labels.append(len(set([i for i in linearized_labels if i != "-100"])))


        num_rows_after_clipping.append(num_rows)
        progress.update()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 num_rows_after_clipping = []
#       5 num_diff_labels = []
# ----> 7 with tqdm(total=len(dataset)) as progress:
#       8     for i in range(len(dataset)):
#       9         table = dataset.iloc[i]
#
# NameError: name 'dataset' is not defined

# %%
data = pd.read_json('../data/final_NER_labeled_dataset_filtered.json')

# %%
len(data)
# Out:
# 51271

# %%
data.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.iloc[0]
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
n_rows=[]
n_columns=[]
n_entities_cell=[]

for i in range(len(data)):
    table=data[i]
    cells = table[0][5]
    entities =table[0][6] 
    
    n_row = cells[-1][0][0]
    n_col = cells[-1][0][1]    

    n_rows.append(n_row)
    n_columns.append(n_col)
    
    n_entities_cell.append(entities)

# %%
mean_rows = np.mean(n_rows)
mean_columns =np.mean(n_columns)
print(mean_rows)
print(mean_columns)
# Out:
# 7.231300345224396
# 4.087183788106337

# %%
# Previously total num of labeled entities : 1 081455, + 810252 as O

# %%
#labels_dict = {"Organization":0,
#"ArchitecturalStructure":1,
#"Event":2,
#"Place":3,
#"Person":4,
#"Work":5}
#labels_dict={v:k for k,v in labels_dict.items()}
#print(labels_dict)

# %%
types_dict={}
for i in range(8):
    types_dict[i]=0

for table in n_entities_cell:
    if table != []:
        for cell in table:
            es=cell[0]            
            for e in es:                
                if e !=[]:
                    types_dict[e[-1]]+=1
print(types_dict)
# Out:
# {0: 504236, 1: 15094, 2: 220739, 3: 66581, 4: 74948, 5: 386955, 6: 571686, 7: 55813}

# %%
# Currently total num of labeled entities: 1 391810, + 504242 as O

# %%
del types_dict[0]

# %%
labels_dict = {  'Activity': 1,
                 'Organisation': 2,
                 'ArchitecturalStructure': 3,
                 'Event': 4,
                 'Place': 5,
                 'Person': 6,
                 'Work': 7,
                }
labels_dict={v:k for k,v in labels_dict.items()}
print(labels_dict)
# Out:
# {1: 'Activity', 2: 'Organisation', 3: 'ArchitecturalStructure', 4: 'Event', 5: 'Place', 6: 'Person', 7: 'Work'}

# %%
labels = [label for label in labels_dict.keys()]
values = [value for value in types_dict.values()]

# %%
data = [value for value in types_dict.values()]
labels = ['Activity', 'Organization', 'ArchitecturalStructure', 'Event', 'Place', 'Person', 'Work']

# Create a barplot using Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.barplot(x=labels, y=data, palette='Pastel1')

ax.set_xlabel('Types')
ax.set_ylabel('Number of entities')

for i, v in enumerate(data):
    ax.text(i, v + 1000, str(v), ha='center', va='bottom')
    
plt.yticks([100000, 200000,300000,400000,500000])
plt.xticks(rotation=15)
plt.tight_layout()
plt.savefig("plots/num_entities_per_type_final.png")
plt.show()
# Out:
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_57054/401211315.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=labels, y=data, palette='Pastel1')

# %%
len(n_entities_cell) #num tables
# Out:
# 51271

# %%
avg_entities_per_cell=[]
sum_entities_per_table=[]

for table in n_entities_cell:
    per_table = 0
    entities_per_cell = []
    
    for cell in table:
        per_cell = 0
        entities = cell[0]
        for e in entities:
            if e[-1] != 0:
                per_cell+=1

        entities_per_cell.append(per_cell)
        per_table += per_cell

    avg_entities_per_cell.append(np.mean(entities_per_cell))
    sum_entities_per_table.append(per_table)

# %%
len(sum_entities_per_table) # number of annotated entities per table
# Out:
# 2000

# %%
max(sum_entities_per_table)
# Out:
# 196

# %%
sns.set(rc={'figure.figsize':(11,6)})

fig, ax = plt.subplots(1)

sns.histplot(sum_entities_per_table,kde=False,ax=ax,stat="count",binrange=[0,130], bins=30, color='steelblue')
ax.set(xlabel='Number of labeled entities per table', ylabel='Number of tables')
#fig.savefig("plots/ser_entities_per_table.png")
# Out:
# [Text(0.5, 0, 'Number of labeled entities per table'),
#  Text(0, 0.5, 'Number of tables')]

# %%
sns.set(rc={'figure.figsize':(11,6)})

fig, ax = plt.subplots(1)

sns.histplot(avg_entities_per_cell,kde=False,ax=ax,stat="count",binrange=[0,5],bins=30, color='steelblue')
ax.set(xlabel='Number of labeled entities per cell - average per table', ylabel='Number of tables')
# Out:
# [Text(0.5, 0, 'Number of labeled entities per cell - average per table'),
#  Text(0, 0.5, 'Number of tables')]

# %% [markdown]
# ## Test set analysis

# %%
seed_nr = 42
generator = torch.Generator().manual_seed(seed_nr)

# %%
train_set, test_set = torch.utils.data.random_split(ner_tables, [49271, 2000], generator=generator)

# %%
len(test_set)
# Out:
# 2000

# %%
n_rows=[]
n_columns=[]
n_entities_cell=[]

for i in test_set.indices:
    table=data.iloc[i]
    cells = table[0][5]
    entities =table[0][6] 
       
    
    n_row = cells[-1][0][0]
    n_col = cells[-1][0][1]    

    n_rows.append(n_row)
    n_columns.append(n_col)
    
    n_entities_cell.append(entities)

# %%
mean_rows = np.mean(n_rows)
mean_columns =np.mean(n_columns)
print(mean_rows)
print(mean_columns)
# Out:
# 7.1905
# 4.0615

# %%
types_dict={}
for i in range(8):
    types_dict[i]=0

for table in n_entities_cell:
    if table != []:
        for cell in table:
            es=cell[0]            
            for e in es:                
                if e !=[]:
                    types_dict[e[-1]]+=1
print(types_dict)
# Out:
# {0: 20141, 1: 704, 2: 8706, 3: 2299, 4: 2679, 5: 15007, 6: 22149, 7: 2285}

# %% [markdown]
# ### to get the plots for test data reexecute the plots above

# %% [markdown]
# ## Plot results

# %% [markdown]
# ### Line plots per model, per class

# %%
 labels_dict = { 'Activity': '1',
                 'Organisation': '2',
                 'ArchitecturalStructure': '3',
                 'Event': '4',
                 'Place': '5',
                 'Person': '6',
                 'Work': '7',
                }
labels_dict={v:k for k,v in labels_dict.items()}
print(labels_dict)
# Out:
# {'1': 'Activity', '2': 'Organisation', '3': 'ArchitecturalStructure', '4': 'Event', '5': 'Place', '6': 'Person', '7': 'Work'}

# %%
model_1 = pd.read_csv(os.path.join('../output', 'results_gpt-35-turbo-instruct_0_bar_True'+'.csv'))
model_1 = model_1.rename(columns=labels_dict)  

model_1 = model_1[model_1['num_tab']<=550]

# %%
model_2 = pd.read_csv(os.path.join('../output', 'results_gpt-35-turbo_0_bar_random'+'.csv'))
model_2 = model_2.rename(columns=labels_dict)  

model_2 = model_2[model_2['num_tab']<=550]

# %%
model_3 = pd.read_csv(os.path.join('../output', 'results_gpt-4_0_bar_random'+'.csv'))
model_3 = model_3.rename(columns=labels_dict)  

model_3 = model_3[model_3['num_tab']<=550]

# %%
sns.set(style="whitegrid")
fig, axs = plt.subplots(4, 2, figsize=(10, 8), sharex=True, sharey=True)
axs[0, 0].plot(model_1['num_tab'], model_1['Organisation'], label='Organisation', linestyle='-', marker='o',color = 'royalblue')
axs[0, 0].plot(model_2['num_tab'], model_2['Organisation'], linestyle='--', marker='o',color = 'royalblue')
axs[0, 0].plot(model_3['num_tab'], model_3['Organisation'], linestyle=':', marker='o',color = 'royalblue')
axs[0, 0].set_title('Organisation')

axs[0, 1].plot(model_1['num_tab'], model_1['Person'], label='Person', linestyle='-', marker='o',color = 'darkorange')
axs[0, 1].plot(model_2['num_tab'], model_2['Person'], linestyle='--', marker='o',color = 'darkorange')
axs[0, 1].plot(model_3['num_tab'], model_3['Person'], linestyle=':', marker='o',color = 'darkorange')
axs[0, 1].set_title('Person')

axs[1, 0].plot(model_1['num_tab'], model_1['Work'], label='Work', linestyle='-', marker='o',color = 'darkseagreen')
axs[1, 0].plot(model_2['num_tab'], model_2['Work'], linestyle='--', marker='o',color = 'darkseagreen')
axs[1, 0].plot(model_3['num_tab'], model_3['Work'], linestyle=':', marker='o',color = 'darkseagreen')
axs[1, 0].set_title('Work')


axs[1, 1].plot(model_1['num_tab'], model_1['Place'], label='Place', linestyle='-', marker='o',color = 'tomato')
axs[1, 1].plot(model_2['num_tab'], model_2['Place'], linestyle='--', marker='o',color = 'tomato')
axs[1, 1].plot(model_3['num_tab'], model_3['Place'], linestyle=':', marker='o',color = 'tomato')
axs[1, 1].set_title('Place')


axs[2, 0].plot(model_1['num_tab'], model_1['Activity'], label='Activity', linestyle='-', marker='o',color = 'gold')
axs[2, 0].plot(model_2['num_tab'], model_2['Activity'], linestyle='--', marker='o',color = 'gold')
axs[2, 0].plot(model_3['num_tab'], model_3['Activity'], linestyle=':', marker='o',color = 'gold')
axs[2, 0].set_title('Activity')

axs[2, 1].plot(model_1['num_tab'], model_1['ArchitecturalStructure'], label='Architectural Structure', linestyle='-', marker='o',color = 'grey')
axs[2, 1].plot(model_2['num_tab'], model_2['ArchitecturalStructure'], linestyle='--', marker='o',color = 'grey')
axs[2, 1].set_title('ArchitecturalStructure')

axs[3, 0].plot(model_1['num_tab'], model_1['Event'], label='Event', linestyle='-', marker='o',color = 'orchid')
axs[3, 0].plot(model_2['num_tab'], model_2['Event'], linestyle='--', marker='o',color = 'orchid')
axs[3, 0].plot(model_3['num_tab'], model_3['Event'], linestyle=':', marker='o',color = 'orchid')
axs[3, 0].set_title('Event')

fig.text(0.5, 0.07, 'Num tables', ha='center', va='center')
fig.text(0.07, 0.5, 'F1 Score', ha='center', va='center', rotation='vertical')

fig.delaxes(axs[3,1])

fig.legend(['GPT-instruct', 'GPT-3.5-turbo', 'GPT-4'], bbox_to_anchor=axs[-1,-1].get_position(), bbox_transform=fig.transFigure)

plt.savefig("../output/plots/"+ "All_class_all_mod_0shot.png")

# %% [markdown]
# ## F1, P and Recall per model

# %%
def plot_results(model_name, shot, labels_dict):
    
    file_name = 'results_{}_{}'.format(model_name, shot)   
    data = pd.read_csv(os.path.join('../output/comma_deli', file_name+'.csv'))
    data = data.rename(columns=labels_dict)  
    
   # data = data[data['num_tab']<=550]
    
    # plot overall metrics    
    sns.set(style="whitegrid")
    plt.figure(figsize=(8, 5))
    plt.plot(data['num_tab'], data['precision'], label='Precision')
    plt.plot(data['num_tab'], data['recall'], label='Recall')
    plt.plot(data['num_tab'], data['f1'], label='F1')
    
    print("precision {}, recall {}, F1 {},".format(data['precision'].mean(), data['recall'].mean(), data['f1'].mean()))

    plt.xlabel('num tables')
    plt.ylabel('Score')
    plt.title('Scores Over num')
    plt.legend() 
    plt.ylim(0, 1)    
    #plt.savefig("../output/plots/"+ "general_"+file_name+".png")
    
    
    # plot Per class
    sns.set(style="whitegrid")
    plt.figure(figsize=(8, 5))
    plt.plot(data['num_tab'], data['Organisation'], label='Organization')
    plt.plot(data['num_tab'], data['Person'], label='Person')
    plt.plot(data['num_tab'], data['Work'], label='Work')
    plt.plot(data['num_tab'], data['Place'], label='Place')

    plt.xlabel('num tables')
    plt.ylabel('Score')
    plt.title('Scores Over num')
    plt.legend() 
    plt.ylim(0, 1) 

    #plt.savefig("../output/plots/"+ "class_"+file_name+".png")
    
    return data

# %%
test = plot_results('gpt-35-turbo-instruct', '0', labels_dict)
test["f1"].mean()
# Out:
# precision 0.5823107636147439, recall 0.4385023882338703, F1 0.5002360992956759,
# 0.5002360992956759

# %%
precision 0.5395309978000151, recall 0.49086658209834705, F1 0.513576457876007

# %%
def plot_barplot(model_name, shot):
    
    file_name = 'results_{}_{}'.format(model_name, shot)   
    data = pd.read_csv(os.path.join('../output/comma_deli', file_name+'.csv'))
    data = data.rename(columns=labels_dict)
    data.fillna(0, inplace=True)
    
    f1 = []
    classes = ['Activity', 'Organisation', 'ArchitecturalStructure','Event', 'Place', 'Person', 'Work']
    for class_name in classes:
        f1.append(data[class_name].mean())
        
    data_class = { 'Class':classes,'F1 Score':f1, 'reduced':True}
    df = pd.DataFrame(data_class)
    
    plt.figure(figsize=(10, 6))
    palette = 'Pastel1'
    for i, row in df.iterrows():    
        sns.barplot(x='Class', y='F1 Score', hue='Class', data=df, palette=palette)
    # Add labels and title
    sns.set(style="whitegrid")
    plt.xticks(rotation=15)
    plt.ylim(0, 0.9)
    plt.xlabel('Class')
    plt.ylabel('Mean F1 Score')
    #plt.title("{}".format(model_name.upper()))
    plt.title("GPT-3.5-turbo-instruct")
    
    #plt.show()
    save_filename = "class_{}_{}.png".format(model_name.upper(), shot)
    
    return df
    
    #plt.savefig(os.path.join("../output/plots", save_filename))

# %%
df_gpt_35_0 = plot_barplot("gpt-4",0)

# %%
df_gpt_35_3_filtered = plot_barplot("gpt-35-turbo-16k",3)

# %%
gpt_inst = pd.concat([df_gpt_35_0,df_gpt_35_3_filtered])

# %%
len(gpt_inst['Class'].unique())
# Out:
# 7

# %%
gpt_inst
# Out:
#                     Class  F1 Score  reduced
# 0                Activity  0.178375    False
# 1            Organisation  0.659078    False
# 2  ArchitecturalStructure  0.659595    False
# 3                   Event  0.540630    False
# 4                   Place  0.772131    False
# 5                  Person  0.772825    False
# 6                    Work  0.653415    False
# 0                Activity  0.000000     True
# 1            Organisation  0.667100     True
# 2  ArchitecturalStructure  0.000000     True
# 3                   Event  0.000000     True
# 4                   Place  0.772237     True
# 5                  Person  0.779054     True
# 6                    Work  0.560651     True

# %%
plt.figure(figsize=(9, 6))
palette = 'muted'

g = sns.catplot(
    data=gpt_inst, kind="bar",
    x='Class', y='F1 Score', hue='reduced',  palette=palette, alpha=.5, height=7.5, dodge=False
)
# Add labels and title
sns.set(style="whitegrid")
plt.xticks(rotation=15)
plt.ylim(0, 0.9)
plt.xlabel('Class', fontsize=16)
plt.ylabel('Mean F1 Score', fontsize=16)
plt.title("GPT-3.5-turbo")

#plt.savefig(os.path.join("../output/plots", "GPT-35-turbo-instruct_both.png"), bbox_inches = "tight")
# Out:
# Text(0.5, 1.0, 'GPT-3.5-turbo')

# %%
gpt_inst
# Out:
#                     Class  F1 Score  example
# 0                Activity  0.007050        0
# 1            Organisation  0.393103        0
# 2  ArchitecturalStructure  0.222632        0
# 3                   Event  0.190559        0
# 4                   Place  0.433990        0
# 5                  Person  0.621621        0
# 6                    Work  0.298078        0
# 0                Activity  0.292466        3
# 1            Organisation  0.637758        3
# 2  ArchitecturalStructure  0.563678        3
# 3                   Event  0.531459        3
# 4                   Place  0.770649        3
# 5                  Person  0.755173        3
# 6                    Work  0.508133        3

# %%
df_gpt_inst_0
# Out:
#                     Class  F1 Score  example
# 0                Activity  0.007050        0
# 1            Organisation  0.393103        0
# 2  ArchitecturalStructure  0.222632        0
# 3                   Event  0.190559        0
# 4                   Place  0.433990        0
# 5                  Person  0.621621        0
# 6                    Work  0.298078        0

# %%
"gpt-4".upper()
# Out:
# 'GPT-4'

# %%
data = pd.read_csv("../output/similarity/results_gpt-4_3_bar.csv")

# %%
data = data.rename(columns=labels_dict)

# %%
data.fillna(0, inplace=True)

# %%
data.head(4)
# Out:
#    num_tab  precision    recall        f1  Activity  Organisation  \
# 0       50   0.721579  0.855529  0.782866  0.315789      0.706994
# 1      100   0.695700  0.770690  0.731278  0.536082      0.629591
# 2      150   0.694521  0.779775  0.734683  0.530303      0.633648
# 3      200   0.695330  0.787403  0.738508  0.476821      0.629891
#
#    ArchitecturalStructure     Event     Place    Person      Work
# 0                0.915751  0.608187  0.875862  0.802708  0.650602
# 1                0.792683  0.640669  0.808219  0.782694  0.773050
# 2                0.810680  0.601660  0.797598  0.789911  0.722944
# 3                0.783158  0.580101  0.798397  0.797975  0.693387

# %%
f1 = []
classes = ['Activity', 'Organisation', 'ArchitecturalStructure','Event', 'Place', 'Person', 'Work']
for class_name in classes:
    f1.append(data[class_name].mean())

# %%
labels_dict
# Out:
# {'1': 'Activity',
#  '2': 'Organisation',
#  '3': 'ArchitecturalStructure',
#  '4': 'Event',
#  '5': 'Place',
#  '6': 'Person',
#  '7': 'Work'}

# %%
llama2_3shot_sim= {5: 0.41476424151909536, 1: 0.22614840989399287, 6: 0.3753812032159689, 7: 0.14384508990318118, 2: 0.3681090693538826, 3: 0.28609625668449196, 4: 0.3216374269005848}
llama2_0shot_sim= {6: 0.03505911129229515, 2: 0.014369106421194431, 3: 0.0036968576709796677, 7: 0.003273322422258592, 5: 0.0006795786612300373}

# %%
df0 = pd.DataFrame(list(labels_dict.items()), columns=['Label', 'Class'])
df0['F1 Score'] = df0['Label'].astype(int).map(llama2_0shot_sim)
df0['k-shot'] = 0

# %%
df3 = pd.DataFrame(list(labels_dict.items()), columns=['Label', 'Class'])
df3['F1 Score'] = df3['Label'].astype(int).map(llama2_3shot_sim)
df3['k-shot'] = 3

# %%
df = pd.concat([df0, df3])
df.fillna(0, inplace=True)

# %%
del df['Label']

# %%
df
# Out:
#   Label                   Class  F1 Score  k-shot
# 0     1                Activity  0.000000       0
# 1     2            Organisation  0.014369       0
# 2     3  ArchitecturalStructure  0.003697       0
# 3     4                   Event  0.000000       0
# 4     5                   Place  0.000680       0
# 5     6                  Person  0.035059       0
# 6     7                    Work  0.003273       0
# 0     1                Activity  0.226148       3
# 1     2            Organisation  0.368109       3
# 2     3  ArchitecturalStructure  0.286096       3
# 3     4                   Event  0.321637       3
# 4     5                   Place  0.414764       3
# 5     6                  Person  0.375381       3
# 6     7                    Work  0.143845       3

# %%
plt.figure(figsize=(9, 6))
palette = 'muted'

g = sns.catplot(
    data=df, kind="bar",
    x='Class', y='F1 Score', hue='k-shot',  palette=palette, alpha=.5, height=7.5, dodge=True
)
# Add labels and title
sns.set(style="whitegrid")
plt.xticks(rotation=15)
plt.ylim(0, 0.9)
plt.xlabel('Class')
plt.ylabel('Mean F1 Score')
plt.title("Llama2")

plt.savefig(os.path.join("../output/plots", "Llama2_both.png"), bbox_inches = "tight")

# %%
plt.figure(figsize=(10, 6))
palette = 'Pastel1'
for i, row in df.iterrows():    
    sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# Add labels and title
sns.set(style="whitegrid")
plt.xticks(rotation=15)
plt.ylim(0, 0.9)
plt.xlabel('Class')
plt.ylabel('Mean F1 Score')
plt.title("Llama2")
plt.savefig("../output/plots/class_Llama2_1_sim.png")
#plt.show()
# Out:
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_3453/2765694205.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Label', y='F1 Score', data=df, palette=palette)

# %%
#sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.bar('Organisation', data['Organisation'].mean(), label='Organization')
plt.bar('Person', data['Person'].mean(), label='Person')
plt.bar('Work', data['Work'].mean(), label='Work')
plt.bar('Place', data['Place'].mean(), label='Place')

plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0, 1) 

# Show the plot
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
plt.plot(data['num_tab'], data['precision'], label='Precision')
plt.plot(data['num_tab'], data['recall'], label='Recall')
plt.plot(data['num_tab'], data['f1'], label='F1')

# Add labels and title
plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0.4, 0.7) 

# Show the plot
plt.show()

# %%
df = plot_results("../output/results_gpt35turbo_3shot_filtered.csv", filtered = True)
# Out:
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_72561/856074508.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Organization'] = df['Organization'].str.replace("{2: ", '')
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_72561/856074508.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Work'] = df['Work'].str.replace("}\)", '')

# %%
df.head(-3)
# Out:
#    precision    recall        f1  Organization    Person     Place      Work  \
# 0   0.560914  0.535433  0.547877      0.352941  0.638522  0.568421  0.017391
# 1   0.604998  0.632972  0.618669      0.462214  0.707277  0.629213  0.069264
# 2   0.564473  0.637077  0.598582      0.401244  0.700730  0.605377  0.058252
# 3   0.557218  0.640650  0.596028      0.435074  0.727021  0.589336  0.066667
#
#    num_tables
# 0         100
# 1         200
# 2         300
# 3         400

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
plt.plot(df['num_tables'], df['precision'], label='Precision')
plt.plot(df['num_tables'], df['recall'], label='Recall')
plt.plot(df['num_tables'], df['f1'], label='F1')

# Add labels and title
plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0.4, 0.7) 

# Show the plot
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.plot(df['num_tables'], df['Organization'], label='Organization')
plt.plot(df['num_tables'], df['Person'], label='Person')
plt.plot(df['num_tables'], df['Work'], label='Work')
plt.plot(df['num_tables'], df['Place'], label='Place')

plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0, 1) 

# Show the plot
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
plt.plot(df['num_tables'], df['Organization'], label='Organization')
plt.plot(df['num_tables'], df['Person'], label='Person')
plt.plot(df['num_tables'], df['Event'], label='Event')
plt.plot(df['num_tables'], df['Activity'], label='Activity')
plt.plot(df['num_tables'], df['Work'], label='Work')
plt.plot(df['num_tables'], df['Place'], label='Place')
plt.plot(df['num_tables'], df['ArchitecturalStructure'], label='ArchitecturalStructure')

plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0, 1) 

# Show the plot
plt.show()

# %%
new_cols = ["precision", "recall", "f1", "Organization", "Person", "Place", "Event", "ArchitecturalStructure", "Work", "Activity"]

# %%
df = pd.read_csv("../output/results_gpt35turbo_3shot.csv", index_col=None, names= new_cols)

# %%
df.head(3)
# Out:
#    precision    recall        f1         Organization               Person  \
# 0   0.545213  0.473441  0.506799  0.45301204819277113   0.6198830409356725
# 1   0.525380  0.452234  0.486071   0.4462452728254997   0.6467338316542087
# 2   0.533333  0.465699  0.497227    0.452054794520548   0.6669404517453799
#
#                  Place                 Event ArchitecturalStructure  \
# 0   0.5098468271334792   0.07909604519774012    0.19402985074626866
# 1   0.4382901866345575   0.05750798722044728     0.2456140350877193
# 2   0.4124946512623021   0.06622516556291391      0.268939393939394
#
#                      Work Activity
# 0   0.12765957446808512})      NaN
# 1   0.08421052631578949})      NaN
# 2   0.19393939393939394})      NaN

# %%
df['Organization'] = df['Organization'].str.replace("{2: ", '')
df['Person'] = df['Person'].str.replace("6: ", '')
df['Work'] = df['Work'].str.replace("7: ", '')
df['Place'] = df['Place'].str.replace("5: ", '')
df['Event'] = df['Event'].str.replace("4: ", '')
df['ArchitecturalStructure'] = df['ArchitecturalStructure'].str.replace("3: ", '')
df['Activity'] = df['Activity'].str.replace("1: ", '')
df['Activity'] = df['Activity'].str.replace("}\)", '')
# Out:
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_72561/447851105.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Organization'] = df['Organization'].str.replace("{2: ", '')
# /var/folders/zs/qtbkgfnj1bd_qhkkmfc294j80000gn/T/ipykernel_72561/447851105.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Activity'] = df['Activity'].str.replace("}\)", '')

# %%
plt.plot(df['num_tables'], df['precision'], label='Precision')
plt.plot(df['num_tables'], df['recall'], label='Recall')
plt.plot(df['num_tables'], df['f1'], label='F1')

# Add labels and title
plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0, 1) 

# Show the plot
plt.show()

# %%
plt.plot(df['num_tables'], df['Organization'], label='Organization')
plt.plot(df['num_tables'], df['Person'], label='Person')
plt.plot(df['num_tables'], df['Event'], label='Event')
plt.plot(df['num_tables'], df['Activity'], label='Activity')
plt.plot(df['num_tables'], df['Work'], label='Work')
plt.plot(df['num_tables'], df['Place'], label='Place')
plt.plot(df['num_tables'], df['ArchitecturalStructure'], label='ArchitecturalStructure')

#Work	Place	Event	ArchitecturalStructure	Activity	f1

# Add labels and title
plt.xlabel('num')
plt.ylabel('Score')
plt.title('Scores Over num')
plt.legend()  # Show legend
plt.ylim(0, 1) 

# Show the plot
plt.show()

# %%
keys = list(labels_dict.keys())

# Create a format string with curly braces for each key
format_string = "Please print the following keys: {}".format(", ".join(["{}"] * len(keys)))

# %%
format_string
# Out:
# 'Please print the following keys: {}, {}, {}, {}, {}, {}, {}'

# %%
print(format_string.format(*keys))
# Out:
# Please print the following keys: 1, 2, 3, 4, 5, 6, 7

# %%
"""Extract entities from the input table using only these types: {}. If the type of the extracted entity is not in this list, please use MISC.""".format(*list(labels_dict.keys()))
# Out:
# 'Extract entities from the input table using only these types: 1, 2. If the type of the extracted entity is not in this list, please use MISC.'
